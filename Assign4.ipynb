# %%
#Enter the first name
print("Enter the first name")
first_name = input()
 
#Enter the last name
print("Enter the last name")
last_name = input()
 
fullnames = first_name + " " + last_name
 
#Enter the email
print("Enter the email address")
email = input()
 
#Enter the phone number
print("Enter the phone number")
phone = input()
 
#Enter the mailing
print("Enter the mailing address")
mailing = input()
 
#Enter the mailing
print("Enter the City")
city = input()
 
#Enter the mailing
print("Enter the zip code")
zipcode = input()

#Enter the State
print("Enter the State")
state = input()



price = float(input("Enter house price: "))
creditscore = int(input("Enter credit score: "))
 
if creditscore >= 780 and creditscore <= 850:
    downPayment = 0
    print("Excellent Credit")
    print("Downpayment = " + str(downPayment))
    price = downPayment + price
    print(price)
 
elif creditscore <= 779 and creditscore >= 740:
    downPayment = 0.2 * price
    print("Very Good Credit")
    print("Downpayment = " + str(downPayment))
    price = downPayment + price
    print(price)
 
elif creditscore <= 739 and creditscore >= 720:
    downPayment = 0.3 * price
    print("Above average Credit")
    print("Downpayment = " + str(downPayment))
 
elif creditscore <= 719 and creditscore >= 680:
    downPayment = 0.6 * price
    print("Average")
    print("Downpayment = " + str(downPayment))
 
elif creditscore <= 679 and creditscore >= 620:
    downPayment = 0.18 * price
    print("Below average")
    print("Downpayment = " + str(downPayment))
 
 
elif creditscore <= 619 and creditscore >= 580:
    downPayment = 0.20 * price
    print("Poor Credit Score")
    print("Downpayment = " + str(downPayment))


elif creditscore <= 579 and creditscore >= 521:
    downPayment = 0.20 * price
    print("Poor Credit Score")
    print("Downpayment = " + str(downPayment))

 
elif creditscore < 520:
     downPayment = 0.25 * price
     print("Poor Credit Score")
     print("Downpayment = " + str(downPayment))

else:
     print("Any number greater than one")

   
print("======================================================================")
print("                 OUTPUT OF THE PROGRAM      ")
print("======================================================================")
print("Full Name: " + fullnames)    
print("Address: " + mailing)
print("City:" + city + (" state:" + state + (" Zipcode:" + zipcode)))
print("    ")
print("New House Price: " + str(price))
print("Down Payment: " + str(downPayment))
print("Credit Score: " + str(creditscore))
print("Credit Status: ")
print(" ")
print("CONGRATULATIONS - YOU NOW OWN YOUR DREAM HOME -" )
# Out:
# Enter the first name
# jJohn
# Enter the last name
# Kamau
# Enter the email address
# jkamau@yahoo.com
# Enter the phone number
# 4044582000
# Enter the mailing address
# 2314 main st.
# Enter the City
# Newla
# Enter the zip code
# 30120
# Enter the State
# GA
# Enter house price: 245000
# Enter credit score: 749
# Very Good Credit
# Downpayment = 49000.0
# 294000.0
# ======================================================================
#                  OUTPUT OF THE PROGRAM
# ======================================================================
# Full Name: jJohn Kamau
# Address: 2314 main st.
# City:Newla state:GA Zipcode:30120
#
# New House Price: 294000.0
# Down Payment: 49000.0
# Credit Score: 749
# Credit Status:
#
# CONGRATULATIONS - YOU NOW OWN YOUR DREAM HOME -
